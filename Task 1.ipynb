# %% [markdown]
# # Ashwini Anandkumar Sharma

# %% [markdown]
# # POSITION :- Data Science Intern
# ## TASK LEVEL : BEGINNER TASK 1
# ## PROJECT NAME : IRIS FLOWER CLASSIFICATION

# %% [markdown]
# # Importing Libraries

# %% [raw]
# import numpy as np
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt
# from warnings import filterwarnings
# filterwarnings('ignore')

# %% [markdown]
# # Loading the Dataset

# %%
df0 = pd.read_csv("iris.data", header=None)
header_list = ["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm", "Species"]
df0.to_csv("Iris.csv", header=header_list, index=False)
df = pd.read_csv("Iris.csv")
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # Data Summarization

# %%
df.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.isnull()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            False         False          False         False    False
# 1            False         False          False         False    False
# 2            False         False          False         False    False
# 3            False         False          False         False    False
# 4            False         False          False         False    False
# ..             ...           ...            ...           ...      ...
# 145          False         False          False         False    False
# 146          False         False          False         False    False
# 147          False         False          False         False    False
# 148          False         False          False         False    False
# 149          False         False          False         False    False
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
df.tail()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica

# %%
df.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
df.groupby('Species').size()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %% [markdown]
# # Data Visualization

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('equal')
colors = ['yellow','brown','orange']
sp = df['Species'].unique()
ct = df['Species'].value_counts().tolist()
ax.pie(ct, labels = sp, autopct='%1.2f%%', colors=colors, shadow=True, startangle=90)
plt.show()

# %% [markdown]
# # Box & Whisker Plot

# %%
sns.pairplot(df, hue='Species', size=3)
plt.show()

# %%
plt.figure(figsize=(20,10))
setosa = df[df['Species'] == "Iris-setosa"]
bp = sns.boxplot(data = setosa, orient="h")
bp.set_title("Iris-Setosa\n", fontsize = 20)
plt.show()

# %%
plt.figure(figsize=(20, 10))
versicolor = df[df['Species'] == "Iris-versicolor"]
bp = sns.boxplot(data = versicolor, orient="h")
bp.set_title("Iris-Versicolor\n", fontsize = 20)
plt.show()

# %%
plt.figure(figsize=(20, 10))
virginica = df[df['Species'] == "Iris-virginica"]
bp = sns.boxplot(data = virginica, orient="h")
bp.set_title("Iris-Virginica\n", fontsize = 20)
plt.show()

# %% [markdown]
# # Histogram

# %%
fig = plt.figure(figsize=(20, 12))
df.hist(ax = fig.gca(), color="seagreen", edgecolor="black")
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
plt.figure(figsize=(20, 10))
plt.scatter(setosa['SepalLengthCm'], setosa['SepalWidthCm'], c="green", label="Iris-Setosa")
plt.scatter(versicolor['SepalLengthCm'],versicolor['SepalWidthCm'], c="black", label="Iris-Versicolor")
plt.scatter(virginica['SepalLengthCm'],virginica['SepalWidthCm'], c="purple", label="Iris-Virginica")
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.title("Sepal Length vs Width\n", fontsize=20)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.scatter(setosa['PetalLengthCm'], setosa['PetalWidthCm'], c="green", label="Iris-Setosa")
plt.scatter(versicolor['PetalLengthCm'],versicolor['PetalWidthCm'], c="black", label="Iris-Versicolor")
plt.scatter(virginica['PetalLengthCm'],virginica['PetalWidthCm'], c="purple", label="Iris-Virginica")
plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.title("Petal Length vs Width\n", fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# # Correlation Matrix

# %%
plt.figure(figsize=(20, 10))
corr_mat = df.corr()
cm = sns.heatmap(corr_mat, annot=True, cmap="seismic")
cm.set_title("Feature Correlation Matrix")
plt.show()

# %% [markdown]
# # Encoding Dependent Variable

# %%
from sklearn.preprocessing import LabelEncoder
X = df.drop(['Species'], 1)
y = df['Species']
le = LabelEncoder()
y = le.fit_transform(y)

# %% [markdown]
# # Splitting dataset training set and test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 1)

# %% [markdown]
# # Selecting Models and Metrics

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
lr = LogisticRegression()
knn = KNeighborsClassifier()
svm = SVC()
nb = GaussianNB()
dt = DecisionTreeClassifier()
rf = RandomForestClassifier()

# %% [markdown]
# # Training and Evaluating Models

# %%
models = [lr, knn, svm, nb, dt, rf]
scores = []
for model in models:
  model.fit(X_train, y_train)
  y_pred = model.predict(X_test)
  scores.append(accuracy_score(y_test, y_pred))
  print("Accuracy of " + type(model).__name__ + " is", accuracy_score(y_test, y_pred))
# Out:
# Accuracy of LogisticRegression is 0.9777777777777777
# Accuracy of KNeighborsClassifier is 0.9777777777777777
# Accuracy of SVC is 0.9777777777777777
# Accuracy of GaussianNB is 0.9333333333333333
# Accuracy of DecisionTreeClassifier is 0.9555555555555556
# Accuracy of RandomForestClassifier is 0.9555555555555556

# %%
results = pd.DataFrame({
    'Models': ['Logistic Regression', 'K-Nearest Neighbors', 'Support Vector Machine', 'Naive Bayes', 'Decision Tree', 'Random Forest'],
    'Accuracy': scores})

results = results.sort_values(by='Accuracy', ascending=False)
print(results)
# Out:
#                    Models  Accuracy
# 0     Logistic Regression  0.977778
# 1     K-Nearest Neighbors  0.977778
# 2  Support Vector Machine  0.977778
# 4           Decision Tree  0.955556
# 5           Random Forest  0.955556
# 3             Naive Bayes  0.933333
